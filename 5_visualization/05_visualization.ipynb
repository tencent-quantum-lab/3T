# %%
from plot_fig_3 import plot_fig3_code
from plot_fig_4 import plot_fig4_code
import matplotlib.pyplot as plt

# %%
print('Visualizing ligand RMSD results for CDK2 protein (20 Angstrom pocket)')
plot_fig3_code('CDK2')
plt.show()
# Out:
# Visualizing ligand RMSD results for CDK2 protein (20 Angstrom pocket)
# CDK2 structure generation RMSD evaluation:
# Dock pose 0  improved: 255 / 308 , d_RMSD: 0.54 +/- 0.67
# Data mean: 6.42 +/- 3.55 Neg mean: 4.86 +/- 3.38 Pos mean: 6.75 +/- 3.49
# Dock pose 1  improved: 252 / 308 , d_RMSD: 0.53 +/- 0.6
# Data mean: 6.75 +/- 3.43 Neg mean: 5.64 +/- 3.02 Pos mean: 7.0 +/- 3.47
# Dock pose 2  improved: 247 / 308 , d_RMSD: 0.5 +/- 0.62
# Data mean: 6.74 +/- 3.49 Neg mean: 5.6 +/- 3.59 Pos mean: 7.01 +/- 3.41

# %%
print('Visualizing ligand RMSD results for CDK2 protein (25 Angstrom pocket)')
plot_fig3_code('CDK2_25A')
plt.show()
# Out:
# Visualizing ligand RMSD results for CDK2 protein (25 Angstrom pocket)
# CDK2_25A structure generation RMSD evaluation:
# Dock pose 0  improved: 246 / 308 , d_RMSD: 0.42 +/- 0.6
# Data mean: 6.42 +/- 3.55 Neg mean: 5.98 +/- 4.51 Pos mean: 6.53 +/- 3.25
# Dock pose 1  improved: 235 / 308 , d_RMSD: 0.43 +/- 0.62
# Data mean: 6.75 +/- 3.44 Neg mean: 5.76 +/- 2.68 Pos mean: 7.05 +/- 3.58
# Dock pose 2  improved: 234 / 308 , d_RMSD: 0.42 +/- 0.58
# Data mean: 6.76 +/- 3.57 Neg mean: 6.32 +/- 4.66 Pos mean: 6.9 +/- 3.14

# %%
print('Visualizing ligand RMSD results for HSP90 protein (20 Angstrom pocket)')
plot_fig3_code('HSP90')
plt.show()
# Out:
# Visualizing ligand RMSD results for HSP90 protein (20 Angstrom pocket)
# HSP90 structure generation RMSD evaluation:
# Dock pose 0  improved: 157 / 223 , d_RMSD: 0.41 +/- 0.66
# Data mean: 6.29 +/- 3.05 Neg mean: 4.69 +/- 2.86 Pos mean: 6.95 +/- 2.88
# Dock pose 1  improved: 150 / 223 , d_RMSD: 0.37 +/- 0.59
# Data mean: 6.62 +/- 2.57 Neg mean: 5.39 +/- 2.47 Pos mean: 7.15 +/- 2.42
# Dock pose 2  improved: 159 / 223 , d_RMSD: 0.33 +/- 0.53
# Data mean: 6.6 +/- 2.64 Neg mean: 4.83 +/- 2.47 Pos mean: 7.17 +/- 2.43

# %%
print('Visualizing ligand RMSD results for HSP90 protein (rigid pocket)')
plot_fig3_code('HSP90_rigid')
plt.show()
# Out:
# Visualizing ligand RMSD results for HSP90 protein (rigid pocket)
# HSP90_rigid structure generation RMSD evaluation:
# Dock pose 0  improved: 157 / 223 , d_RMSD: 0.2 +/- 0.41
# Data mean: 6.29 +/- 3.05 Neg mean: 6.02 +/- 2.7 Pos mean: 6.4 +/- 3.18
# Dock pose 1  improved: 150 / 223 , d_RMSD: 0.2 +/- 0.46
# Data mean: 6.62 +/- 2.57 Neg mean: 6.37 +/- 2.44 Pos mean: 6.72 +/- 2.61
# Dock pose 2  improved: 133 / 223 , d_RMSD: 0.18 +/- 0.46
# Data mean: 6.6 +/- 2.64 Neg mean: 6.21 +/- 2.85 Pos mean: 6.82 +/- 2.48

# %%
print('Visualizing ligand RMSD results for FXA protein (20 Angstrom pocket)')
plot_fig3_code('FXA')
plt.show()
# Out:
# Visualizing ligand RMSD results for FXA protein (20 Angstrom pocket)
# FXA structure generation RMSD evaluation:
# Dock pose 0  improved: 62 / 106 , d_RMSD: 0.16 +/- 0.6
# Data mean: 5.0 +/- 3.54 Neg mean: 3.29 +/- 3.21 Pos mean: 6.21 +/- 3.26
# Dock pose 1  improved: 65 / 106 , d_RMSD: 0.19 +/- 0.6
# Data mean: 5.72 +/- 3.44 Neg mean: 4.08 +/- 3.32 Pos mean: 6.76 +/- 3.09
# Dock pose 2  improved: 78 / 106 , d_RMSD: 0.34 +/- 0.58
# Data mean: 6.67 +/- 3.02 Neg mean: 6.61 +/- 2.85 Pos mean: 6.69 +/- 3.07

# %%
print('Visualizing ligand classification statistics for CDK2 protein (25 Angstrom pocket) vs standard docking')
plot_fig4_code('CDK2_25A')
plt.show()
# Out:
# Visualizing ligand classification statistics for CDK2 protein (25 Angstrom pocket) vs standard docking
# CDK2_25A classification metrics (30x4-cv, 120 data points):
# AUC-ROC: 0.9347604166666668 +/- 0.014348644674430255
# NEF_Ra: 0.7708239999999998 +/- 0.030039212328776762

# %%
print('Visualizing ligand classification statistics for HSP90 protein (20 Angstrom pocket) vs standard docking')
plot_fig4_code('HSP90')
plt.show()
# Out:
# Visualizing ligand classification statistics for HSP90 protein (20 Angstrom pocket) vs standard docking
# HSP90 classification metrics (30x4-cv, 120 data points):
# AUC-ROC: 0.9488385000000001 +/- 0.018411117051480973
# NEF_Ra: 0.8506782500000001 +/- 0.03487299166648644

# %%
print('Visualizing ligand classification statistics for CDK2 protein (20 Angstrom pocket) vs standard docking')
plot_fig4_code('CDK2')
plt.show()
# Out:
# Visualizing ligand classification statistics for CDK2 protein (20 Angstrom pocket) vs standard docking
# CDK2 classification metrics (30x4-cv, 120 data points):
# AUC-ROC: 0.8282803333333334 +/- 0.01990768498734987
# NEF_Ra: 0.46870399999999995 +/- 0.03708855806040456

# %%
print('Visualizing ligand classification statistics for FXA protein (20 Angstrom pocket) vs standard docking')
plot_fig4_code('FXA')
plt.show()
# Out:
# Visualizing ligand classification statistics for FXA protein (20 Angstrom pocket) vs standard docking
# FXA classification metrics (30x4-cv, 120 data points):
# AUC-ROC: 0.9132335833333334 +/- 0.018381292065386908
# NEF_Ra: 0.5844095 +/- 0.04277426644315481

# %%
print('Visualizing ligand classification statistics for HSP90 protein (rigid pocket) vs standard docking')
plot_fig4_code('HSP90_rigid')
plt.show()
# Out:
# Visualizing ligand classification statistics for HSP90 protein (rigid pocket) vs standard docking
# HSP90_rigid classification metrics (30x4-cv, 120 data points):
# AUC-ROC: 0.8304276666666666 +/- 0.024026944414321367
# NEF_Ra: 0.5242330833333333 +/- 0.04194161733481105
